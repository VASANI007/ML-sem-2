# %%
# Write a Python program to detect outliers in a dataset. 
import numpy as np 
# Sample dataset 
data = np.array([10, 12, 14, 15, 18, 20, 22, 25, 100]) 
print("Original Data:", data) 
# Step 1: Calculate Q1 and Q3 
Q1 = np.percentile(data, 25) 
Q3 = np.percentile(data, 75)
# Out:
# Original Data: [ 10  12  14  15  18  20  22  25 100]

# %%
# Step 2: Calculate IQR 
IQR = Q3 - Q1 
# Step 3: Define lower and upper bounds 
lower_bound = Q1 - 1.5 * IQR 
upper_bound = Q3 + 1.5 * IQR

# %%
# Step 4: Detect outliers 
outliers = data[(data < lower_bound) | (data > upper_bound)] 
print("Lower Bound:", lower_bound) 
print("Upper Bound:", upper_bound)  
print("Outliers detected:", outliers)
# Out:
# Lower Bound: 2.0
# Upper Bound: 34.0
# Outliers detected: [100]

# %%
import matplotlib.pyplot as plt
data = [10,12,14,18,20,25,100]
plt.boxplot(data)
plt.title("Boxplot")
plt.show()
